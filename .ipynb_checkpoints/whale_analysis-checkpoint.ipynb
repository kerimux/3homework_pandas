# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports, import all necessary libraries and print current working dicertory
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

# !pwd
# Out:
# /Users/kerim/Desktop/Assignment/3homework_pandas

# %%
# Create path and read file data using Pandas and Path libraries
whale_returns = Path ('Resources/whale_returns.csv')
algo_returns = Path ('Resources/algo_returns.csv')
sp500_history = Path ('Resources/sp500_history.csv')

whale_returns = pd.read_csv(whale_returns, index_col="Date", parse_dates=True)
algo_returns = pd.read_csv(algo_returns, index_col="Date", parse_dates=True)
sp500 = pd.read_csv(sp500_history, index_col="Date", parse_dates=True)
# Out:
# /var/folders/_6/5tg9nlfd0rq_92tkjdh9t2p80000gn/T/ipykernel_14995/1015841454.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500 = pd.read_csv(sp500_history, index_col="Date", parse_dates=True)

# %%
# Read provided data for whales portfolio, check how it looks
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Read provided data for algos portfolio, check how it looks
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Read provided data for Sp 500 portfolio, check how it looks
sp500
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns, Count nulls, Drop nulls
whale_returns.head()
whale_returns.isnull()
whale_returns.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns, Count nulls, Drop nulls
algo_returns.head()
algo_returns.isnull()
algo_returns.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices,  Check Data Types
sp500['Close']
sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types, drop $ sign and set data as float. 
# Using '.str.replace' function to drop $ sign and using '.astype' function to change type to float 
sp500['Close'] = sp500['Close'].str.replace('$', '').astype(float)
sp500.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Daily Returns of sp500 using '.pc_change' function and Drop nulls 
sp500_returns = sp500.pct_change().dropna()
sp500_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.columns = ['SP500']
sp500_returns
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
# Use 'concat' function to combine all DataFrame 
combined_returns = pd.concat([whale_returns,algo_returns,sp500_returns], axis='columns', join="inner")
combined_returns.head().dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# 2015-03-06 -0.011460 -0.003929

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios, set size 'figsize=' and name 'title=' you want to display
combined_returns.plot(figsize=(20,10),title='Combined returns', legend=True)
# Out:
# <Axes: title={'center': 'Combined returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# The cumulative returns are calculated using the formula '(1 + daily_returns).cumprod() - 1'
cumulative_returns = (1 + combined_returns).cumprod() - 1

# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10), title='Cumulative Returns')
# Out:
# <Axes: title={'center': 'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_volatility = combined_returns.std()
# Calculate  the daily standard deviation of S&P 500
sp500_volatility = combined_returns['SP500'].std()
sp500_volatility
# Out:
# 0.008584076593970712

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Determine which portfolios are riskier than the S&P 500
daily_volatility.sort_values(inplace=True)
daily_volatility
# Out:
# PAULSON & CO.INC.              0.007026
# Algo 1                         0.007624
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 2                         0.008338
# SP500                          0.008584
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
# Sort volatility in ascending order
annualized_volatility = combined_returns.std() * np.sqrt(252)
annualized_volatility.sort_values(inplace=True)
annualized_volatility
# Out:
# PAULSON & CO.INC.              0.111527
# Algo 1                         0.121026
# SOROS FUND MANAGEMENT LLC      0.125348
# Algo 2                         0.132357
# SP500                          0.136268
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# dtype: float64

# %%
# Iterate through each item (portfolio and its risk). 
# Check whether its risk (daily standard deviation) is greater than the risk of the SP 500. 
# If it is, print a message indicating that the portfolio is riskier than the SP 500.

for combined_returns, risk in daily_volatility.items():
    if risk > daily_volatility['SP500']:
        print(f'{combined_returns} is more riskier than the S&P 500')
# Out:
# TIGER GLOBAL MANAGEMENT LLC is more riskier than the S&P 500
# BERKSHIRE HATHAWAY INC is more riskier than the S&P 500

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Concat portfolio returns 
combined_returns = pd.concat([sp500_returns, whale_returns,algo_returns], axis=1, join="inner")

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
# The rolling function with the std() method is applied to each column (portfolio) in the combined_returns
rolling21_combined_std = combined_returns.rolling(window=21).std().plot(figsize=(20,10))

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation, Use '.corr' function
combined_correlation = combined_returns.corr()

# Display de correlation matrix
sns.heatmap(combined_correlation, vmin=-1, vmax=1, annot=True)

# Summary: comparable porfolios has week (positive and negative) correlation to the market (SP 500)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio and Sp500
berkshire_covariance = combined_returns['BERKSHIRE HATHAWAY INC'].cov(combined_returns['SP500'])
sp500_covariance = combined_returns['SP500'].cov(combined_returns['SP500'])

# Calculate variance of S&P 500
sp500_variance = combined_returns['SP500'].var()

# Computing beta 'covariance / variance 
berkshire_beta = berkshire_covariance / sp500_variance
sp500_beta = sp500_covariance / sp500_variance

# Plot rolling beta trend of covariance to variance and aslo variance to variance for visualization
rolling21_berkshire_covariance = combined_returns['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(combined_returns['SP500'])
rolling21_sp500_covariance = combined_returns['SP500'].rolling(window=21).cov(combined_returns['SP500'])

rolling21_sp500_variance = combined_returns['SP500'].rolling(window=21).var()
rolling21_berkshire_beta = rolling21_berkshire_covariance / rolling21_sp500_variance
rolling21_sp500_beta = rolling21_sp500_covariance / rolling21_sp500_variance

ax = rolling21_berkshire_beta.plot(figsize=(20,10), title='BERKSHIRE HATHAWAY INC Rolling 21-Day Beta', label='BERKSHIRE HATHAWAY INC', legend=True)
rolling21_sp500_beta.plot(ax=ax, label='SP 500', legend=True)

# A beta of 1 indicates that the asset tends to move with the market, 
# a beta greater than 1 indicates higher volatility than the market, 
# a beta less than 1 indicates lower volatility than the market.
# Out:
# <Axes: title={'center': 'BERKSHIRE HATHAWAY INC Rolling 21-Day Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
# Set the half-life (span) for the EWMA calculation
half_life = 21

# Calculate the EWMA for each portfolio using std as the metric
portfolio_ewma = combined_returns['BERKSHIRE HATHAWAY INC'].ewm(span=half_life).std()

# Print or use the resulting DataFrame as needed
portfolio_ewma.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios. Calculate sharpe ratio assuming risk free rate is 0
risk_free = 0
annualized_sharpe = ((combined_returns.mean() - risk_free) / (combined_returns.std() * np.sqrt(252)))

# %%
# Visualize the sharpe ratios as a bar plot
annualized_sharpe.plot(kind='bar', title='Annualized Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Annualized Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# #### Algorithmic trading 1 has outperformed both the market (S&P 500) and the whales portfolios.
# #### Algorithmic trading 2 has outperformed the market (S&P 500) and most of the whales portfolios except BERKSHIRE HATHAWAY INC.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# First import libraries
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
from datetime import datetime, date, timedelta
# %matplotlib inline 
# !pwd
# Out:
# /Users/kerim/Desktop/Assignment/3homework_pandas

# %%
# Create path and open data
sp_500_path = Path ('Resources/portfolio/spy.csv')
microsoft_path = Path ('Resources/portfolio/microsoft.csv')
apple_path = Path ('Resources/portfolio/apple.csv')
tesla_path = Path ('Resources/portfolio/tesla.csv')
amazon_path = Path ('Resources/portfolio/amazon.csv')
costco_path = Path ('Resources/portfolio/costco.csv')

# Reading data from stocks
spy500 = pd.read_csv(sp_500_path, index_col="Date", parse_dates=True)
microsoft = pd.read_csv(microsoft_path, index_col="Date", parse_dates=True)
apple = pd.read_csv(apple_path, index_col="Date", parse_dates=True)
tesla = pd.read_csv(tesla_path, index_col="Date", parse_dates=True)
amazon = pd.read_csv(amazon_path, index_col="Date", parse_dates=True)
costco = pd.read_csv(costco_path, index_col="Date", parse_dates=True)

# %%
# drop na, drop duplicates and clean data
spy500.isnull().dropna().drop_duplicates()
microsoft.isnull().dropna().drop_duplicates()
apple.isnull().dropna().drop_duplicates()
tesla.isnull().dropna().drop_duplicates()
amazon.isnull().dropna().drop_duplicates()
costco.isnull().dropna().drop_duplicates()
spy500
# Out:
#                       Close
# Date
# 2015-11-19 16:00:00  208.55
# 2015-11-20 16:00:00  209.31
# 2015-11-23 16:00:00  209.07
# 2015-11-24 16:00:00  209.35
# 2015-11-25 16:00:00  209.32
# ...                     ...
# 2023-11-08 16:00:00  437.25
# 2023-11-09 16:00:00  433.84
# 2023-11-10 16:00:00  440.61
# 2023-11-13 16:00:00  440.19
# 2023-11-14 16:00:00  448.73
#
# [2010 rows x 1 columns]

# %%
# Rename columns name
columns = ["SP500"]
spy500.columns = columns

columns = ["APPL"]
apple.columns = columns

columns = ["MSFT"]
microsoft.columns = columns

columns = ["TSLA"]
tesla.columns = columns

columns = ["COST"]
costco.columns = columns

columns = ["AMZN"]
amazon.columns = columns
apple
# Out:
#                        APPL
# Date
# 2015-11-19 16:00:00   29.70
# 2015-11-20 16:00:00   29.83
# 2015-11-23 16:00:00   29.44
# 2015-11-24 16:00:00   29.72
# 2015-11-25 16:00:00   29.51
# ...                     ...
# 2023-11-08 16:00:00  182.89
# 2023-11-09 16:00:00  182.41
# 2023-11-10 16:00:00  186.40
# 2023-11-13 16:00:00  184.80
# 2023-11-14 16:00:00  187.44
#
# [2010 rows x 1 columns]

# %%
# Combine all stocks in a single DataFrame, 
# Reorganize portfolio data by having a column per symbol
portfolio = pd.concat([spy500, apple, tesla, microsoft, amazon, costco], axis='columns', join="inner")
portfolio
# Out:
#                       SP500    APPL    TSLA    MSFT    AMZN    COST
# Date
# 2015-11-19 16:00:00  208.55   29.70   14.79   53.94   33.06  162.83
# 2015-11-20 16:00:00  209.31   29.83   14.67   54.19   33.42  163.10
# 2015-11-23 16:00:00  209.07   29.44   14.52   54.19   33.95  163.45
# 2015-11-24 16:00:00  209.35   29.72   14.55   54.25   33.56  162.19
# 2015-11-25 16:00:00  209.32   29.51   15.31   53.69   33.77  162.39
# ...                     ...     ...     ...     ...     ...     ...
# 2023-11-03 16:00:00  434.69  176.65  219.96  352.80  138.60  560.90
# 2023-11-06 16:00:00  435.69  179.23  219.27  356.53  139.74  569.82
# 2023-11-07 16:00:00  436.93  181.82  222.18  360.53  142.71  571.27
# 2023-11-08 16:00:00  437.25  182.89  222.11  363.20  142.08  567.38
# 2023-11-09 16:00:00  433.84  182.41  209.98  360.69  140.60  563.27
#
# [2003 rows x 6 columns]

# %%
# Reset Date index
portfolio.reset_index()
# Out:
#                     Date   SP500    APPL    TSLA    MSFT    AMZN    COST
# 0    2015-11-19 16:00:00  208.55   29.70   14.79   53.94   33.06  162.83
# 1    2015-11-20 16:00:00  209.31   29.83   14.67   54.19   33.42  163.10
# 2    2015-11-23 16:00:00  209.07   29.44   14.52   54.19   33.95  163.45
# 3    2015-11-24 16:00:00  209.35   29.72   14.55   54.25   33.56  162.19
# 4    2015-11-25 16:00:00  209.32   29.51   15.31   53.69   33.77  162.39
# ...                  ...     ...     ...     ...     ...     ...     ...
# 1998 2023-11-03 16:00:00  434.69  176.65  219.96  352.80  138.60  560.90
# 1999 2023-11-06 16:00:00  435.69  179.23  219.27  356.53  139.74  569.82
# 2000 2023-11-07 16:00:00  436.93  181.82  222.18  360.53  142.71  571.27
# 2001 2023-11-08 16:00:00  437.25  182.89  222.11  363.20  142.08  567.38
# 2002 2023-11-09 16:00:00  433.84  182.41  209.98  360.69  140.60  563.27
#
# [2003 rows x 7 columns]

# %%
# Calculate daily returns, Drop NAs, Display sample data
portfolio_returns = portfolio.pct_change().dropna()
spy500_returns = spy500.pct_change().dropna()
portfolio_returns
# Out:
#                         SP500      APPL      TSLA      MSFT      AMZN  \
# Date
# 2015-11-20 16:00:00  0.003644  0.004377 -0.008114  0.004635  0.010889
# 2015-11-23 16:00:00 -0.001147 -0.013074 -0.010225  0.000000  0.015859
# 2015-11-24 16:00:00  0.001339  0.009511  0.002066  0.001107 -0.011487
# 2015-11-25 16:00:00 -0.000143 -0.007066  0.052234 -0.010323  0.006257
# 2015-11-27 16:00:00  0.001147 -0.002033  0.008491  0.004470 -0.003257
# ...                       ...       ...       ...       ...       ...
# 2023-11-03 16:00:00  0.009123 -0.005181  0.006636  0.012862  0.003839
# 2023-11-06 16:00:00  0.002300  0.014605 -0.003137  0.010573  0.008225
# 2023-11-07 16:00:00  0.002846  0.014451  0.013271  0.011219  0.021254
# 2023-11-08 16:00:00  0.000732  0.005885 -0.000315  0.007406 -0.004415
# 2023-11-09 16:00:00 -0.007799 -0.002625 -0.054613 -0.006911 -0.010417
#
#                          COST
# Date
# 2015-11-20 16:00:00  0.001658
# 2015-11-23 16:00:00  0.002146
# ...

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights, Calculate portfolio return, Display sample data

weights = [0.00, 0.30, 0.20, 0.20, 0.15, 0.15]
portfolio_weight = portfolio_returns.dot(weights)
portfolio_weight.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std` and sort in ascending order
portfolio_annualstd = portfolio_returns.std() * np.sqrt(252)
portfolio_annualstd.sort_values(ascending=True)
# Out:
# SP500    0.185555
# COST     0.223279
# MSFT     0.278622
# APPL     0.294649
# AMZN     0.333076
# TSLA     0.582779
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
portfolio_rollingstd21 = portfolio_returns.rolling(window=21).std()
# Plot rolling standard deviation
portfolio_rollingstd21.plot(figsize=(20,10), title='Rolling standard deviation with 21-Day window')
# Out:
# <Axes: title={'center': 'Rolling standard deviation with 21-Day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
correlation = portfolio_returns.corr()
correlation
# Out:
#           SP500      APPL      TSLA      MSFT      AMZN      COST
# SP500  1.000000  0.769469  0.468084  0.813126  0.635664  0.599503
# APPL   0.769469  1.000000  0.439308  0.715815  0.592021  0.503037
# TSLA   0.468084  0.439308  1.000000  0.425177  0.408035  0.281902
# MSFT   0.813126  0.715815  0.425177  1.000000  0.675010  0.533375
# AMZN   0.635664  0.592021  0.408035  0.675010  1.000000  0.440370
# COST   0.599503  0.503037  0.281902  0.533375  0.440370  1.000000

# %%
# Calculate and plot the correlation
sns.heatmap(correlation, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate covariance of all daily returns of portfolio vs SP500
rolling_apple_cov = portfolio_returns['APPL'].rolling(window=60).cov(portfolio_returns['SP500'])
rolling_tesla_cov = portfolio_returns['TSLA'].rolling(window=60).cov(portfolio_returns['SP500'])
rolling_microsoft_cov = portfolio_returns['MSFT'].rolling(window=60).cov(portfolio_returns['SP500'])
rolling_amazon_cov = portfolio_returns['AMZN'].rolling(window=60).cov(portfolio_returns['SP500'])
rolling_costco_cov = portfolio_returns['COST'].rolling(window=60).cov(portfolio_returns['SP500'])

# Define variance 
rolling_spy500_var = (portfolio_returns['SP500']).rolling(window=60).var()

#Calculate 60_day rolling beta of stocks in the portfolio vs Variance
rolling_apple_beta = rolling_apple_cov / rolling_spy500_var
rolling_tesla_beta = rolling_tesla_cov / rolling_spy500_var
rolling_microsoft_beta = rolling_microsoft_cov / rolling_spy500_var
rolling_amazon_beta = rolling_amazon_cov / rolling_spy500_var
rolling_costco_beta = rolling_costco_cov / rolling_spy500_var


# Plot rolling beta and overlay different stock betas
ax = rolling_apple_beta.plot(figsize=(20,10), title='Rolling beta of portfolio with 60-Day window', label='AAPL', legend=True)
rolling_tesla_beta.plot(ax=ax, label='TSLA', legend=True)
rolling_microsoft_beta.plot(ax=ax, label='MSFT', legend=True)
rolling_amazon_beta.plot(ax=ax, label='AMZN', legend=True)
rolling_costco_beta.plot(ax=ax, label='COST', legend=True)
# Out:
# <Axes: title={'center': 'Rolling beta of portfolio with 60-Day window'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
# Visualize the sharpe ratios as a bar plot
annual_sharpe_ratio = (portfolio_returns.mean() - portfolio_returns['SP500'].mean()) / (portfolio_returns.std() * np.sqrt(252))
annual_sharpe_ratio.plot(kind='bar', title='Annualized Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Annualized Sharpe Ratios'}>

# %%
combined_returns = ((portfolio_returns['APPL']) + (portfolio_returns['MSFT']) + (portfolio_returns['TSLA']) + (portfolio_returns['AMZN']) + (portfolio_returns['COST']))
combined_returns
# Out:
# Date
# 2015-11-20 16:00:00    0.013446
# 2015-11-23 16:00:00   -0.005294
# 2015-11-24 16:00:00   -0.006512
# 2015-11-25 16:00:00    0.042336
# 2015-11-27 16:00:00    0.014999
#                          ...
# 2023-11-03 16:00:00    0.027023
# 2023-11-06 16:00:00    0.046169
# 2023-11-07 16:00:00    0.062740
# 2023-11-08 16:00:00    0.001752
# 2023-11-09 16:00:00   -0.081808
# Length: 2002, dtype: float64

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_returns).cumprod() - 1
cumulative_spy500 = (1 + portfolio_returns['SP500']).cumprod() - 1
# Plot cumulative returns
ax = cumulative_returns.plot(figsize=(15,10), title='Cumulative Returns of Portfolio compared to Market', label='Portfolio', legend=True)
cumulative_spy500.plot(ax=ax, label='SP 500', legend=True)
# Out:
# <Axes: title={'center': 'Cumulative Returns of Portfolio compared to Market'}, xlabel='Date'>

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns2 = (1 + portfolio_returns).cumprod() - 1
# Plot cumulative returns
cumulative_returns2.plot(figsize=(15,10), title='Cumulative Returns', label='Portfolio', legend=True)
# Out:
# <Axes: title={'center': 'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
# Over time,  my portfolio has consistently outperformed the S&P500, 
# however my portfolio has high volatility and strong correlation to the market.

# %%
portfolio.to_csv("My_Portfolio.csv", index=False)
